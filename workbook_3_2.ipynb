# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
import numpy as np

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
point1 = [0,0,0]
point2 = [3, 3, 3]
point3 = [3, 0, 3]
point4 = [0, 3, 3]

def sqr_euclidean_distance(v1, v2):
    return sum((x-y) ** 2 for x, y in zip(v1, v2))
def weighted_euclidean_distance(v1, v2, w):
    return sum((x-y) ** 2 * s for x,y,s in zip(v1,v2,w)) ** 0.5
def manhattan_distance(v1,v2):
    return sum(abs(x-y) for(x,y) in zip(v1,v2))
def chebyshev_distance(v1,v2):
    return max(abs(x - y) for (x, y) in zip(v1, v2))


def Replase(x):
    return x[0], x[1], x[2]
a = ax.scatter(*Replase(point1))
b = ax.scatter(*Replase(point2))
c = ax.scatter(*Replase(point3))
d = ax.scatter(*Replase(point4))
plt.show()

print("euclidean")
print("start point 1")
print("sqr_euclidean_distance 1-2 point", sqr_euclidean_distance(np.array(point1), np.array(point2)))
print("sqr_euclidean_distance 1-3 point", sqr_euclidean_distance(np.array(point1), np.array(point3)))
print("sqr_euclidean_distance 1-4 point", sqr_euclidean_distance(np.array(point1), np.array(point4)))
print("start point 2")
print("sqr_euclidean_distance 2-1 point", sqr_euclidean_distance(np.array(point2), np.array(point1)))
print("sqr_euclidean_distance 2-3 point", sqr_euclidean_distance(np.array(point2), np.array(point3)))
print("sqr_euclidean_distance 2-4 point", sqr_euclidean_distance(np.array(point2), np.array(point4)))
print("start point 3")
print("sqr_euclidean_distance 3-1 point", sqr_euclidean_distance(np.array(point3), np.array(point1)))
print("sqr_euclidean_distance 3-2 point", sqr_euclidean_distance(np.array(point3), np.array(point2)))
print("sqr_euclidean_distance 3-4 point", sqr_euclidean_distance(np.array(point3), np.array(point4)))
print("start point 4")
print("sqr_euclidean_distance 4-1 point", sqr_euclidean_distance(np.array(point4), np.array(point2)))
print("sqr_euclidean_distance 4-2 point", sqr_euclidean_distance(np.array(point4), np.array(point3)))
print("sqr_euclidean_distance 4-3 point", sqr_euclidean_distance(np.array(point4), np.array(point4)))
print("euclidean")
print("start point 1")
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point1), np.array(point2), np.array(point3)))
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point1), np.array(point3), np.array(point3)))
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point1), np.array(point4), np.array(point3)))
print("start point 2")
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point2), np.array(point1), np.array(point3)))
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point2), np.array(point3), np.array(point3)))
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point2), np.array(point4), np.array(point3)))
print("start point 3")
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point3), np.array(point2), np.array(point3)))
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point3), np.array(point1), np.array(point3)))
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point3), np.array(point4), np.array(point3)))
print("start point 4")
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point4), np.array(point2), np.array(point3)))
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point4), np.array(point3), np.array(point3)))
print("weighted_euclidean_distance", weighted_euclidean_distance(np.array(point4), np.array(point1), np.array(point3)))
print("manhattan")
print("start point 1")
print("manhattan_distance 1-2 point", manhattan_distance(np.array(point1), np.array(point2)))
print("manhattan_distance 1-3 point", manhattan_distance(np.array(point1), np.array(point3)))
print("manhattan_distance 1-4 point", manhattan_distance(np.array(point1), np.array(point4)))
print("start point 2")
print("manhattan_distance 2-1 point", manhattan_distance(np.array(point2), np.array(point1)))
print("manhattan_distance 2-3 point", manhattan_distance(np.array(point2), np.array(point3)))
print("manhattan_distance 2-4 point", manhattan_distance(np.array(point2), np.array(point4)))
print("start point 3")
print("manhattan_distance 3-1 point", manhattan_distance(np.array(point3), np.array(point1)))
print("manhattan_distance 3-2 point", manhattan_distance(np.array(point3), np.array(point2)))
print("manhattan_distance 3-4 point", manhattan_distance(np.array(point3), np.array(point4)))
print("start point 4")
print("manhattan_distance 4-1 point", manhattan_distance(np.array(point4), np.array(point2)))
print("manhattan_distance 4-2 point", manhattan_distance(np.array(point4), np.array(point3)))
print("manhattan_distance 4-3 point", manhattan_distance(np.array(point4), np.array(point4)))
print("euclidean")
print("start point 1")
print("chebyshev_distance 1-2 point", chebyshev_distance(np.array(point1), np.array(point2)))
print("chebyshev_distance 1-3 point", chebyshev_distance(np.array(point1), np.array(point3)))
print("chebyshev_distance 1-4 point", chebyshev_distance(np.array(point1), np.array(point4)))
print("start point 2")
print("chebyshev_distance 2-1 point", chebyshev_distance(np.array(point2), np.array(point1)))
print("chebyshev_distance 2-3 point", chebyshev_distance(np.array(point2), np.array(point3)))
print("chebyshev_distance 2-4 point", chebyshev_distance(np.array(point2), np.array(point4)))
print("start point 3")
print("chebyshev_distance 3-1 point", chebyshev_distance(np.array(point3), np.array(point1)))
print("chebyshev_distance 3-2 point", chebyshev_distance(np.array(point3), np.array(point2)))
print("chebyshev_distance 3-4 point", chebyshev_distance(np.array(point3), np.array(point4)))
print("start point 4")
print("chebyshev_distance 4-1 point", chebyshev_distance(np.array(point4), np.array(point2)))
print("chebyshev_distance 4-2 point", chebyshev_distance(np.array(point4), np.array(point3)))
print("chebyshev_distance 4-3 point", chebyshev_distance(np.array(point4), np.array(point4)))
# Out:
# euclidean
# start point 1
# sqr_euclidean_distance 1-2 point 27
# sqr_euclidean_distance 1-3 point 18
# sqr_euclidean_distance 1-4 point 18
# start point 2
# sqr_euclidean_distance 2-1 point 27
# sqr_euclidean_distance 2-3 point 9
# sqr_euclidean_distance 2-4 point 9
# start point 3
# sqr_euclidean_distance 3-1 point 18
# sqr_euclidean_distance 3-2 point 9
# sqr_euclidean_distance 3-4 point 18
# start point 4
# sqr_euclidean_distance 4-1 point 9
# sqr_euclidean_distance 4-2 point 18
# sqr_euclidean_distance 4-3 point 0
# euclidean
# start point 1
# weighted_euclidean_distance 7.3484692283495345
# weighted_euclidean_distance 7.3484692283495345
# weighted_euclidean_distance 5.196152422706632
# start point 2
# weighted_euclidean_distance 7.3484692283495345
# weighted_euclidean_distance 0.0
# weighted_euclidean_distance 5.196152422706632
# start point 3
# weighted_euclidean_distance 0.0
# weighted_euclidean_distance 7.3484692283495345
# weighted_euclidean_distance 5.196152422706632
# ...

# %%
#Задача2.

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

iris = sns.load_dataset('iris')

X_train, X_test, y_train, y_test = train_test_split(
    iris.iloc[:, :-1],
    iris.iloc[:, -1],
    test_size = 0.15
)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

X_train.head()
y_train.head()

mode1 = KNeighborsClassifier(n_neighbors = 3)
mode1.fit(X_train, y_train)

y_pred = mode1.predict(X_test)
y_pred

plt.figure(figsize=(10,7))
sns.scatterplot(x='petal_width', y='petal_length', data=iris, hue='species', s=70)
plt.xlabel('Длина леписткаб см')
plt.ylabel('Ширина лепистка см')
plt.legend(loc=2)
plt.grid()

for i in range(len(y_test)):
    if np.array(y_test)[i] != y_pred[i]:
        plt.scatter(X_test.iloc[i, 3], X_test.iloc[i, 2], color='red', s=150)
print(f'accuracy: {accuracy_score(y_test, y_pred) :.3}')
# Out:
# /Users/ilazotov/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# accuracy: 1.0
